# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
train_data=pd.read_csv(r"C:\Users\visha\first_ML_Course\Dataset\Blue Book Bulldozers\Train.csv")
print(train_data.head())
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3185: DtypeWarning: Columns (13,39,40,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# ...

# %%
plt.plot(np.array(train_data["SalePrice"]))

# %%
plt.figure(figsize=(50,12))
sns.set_style("whitegrid")

plt.plot(train_data["SalesID"],train_data["SalePrice"],marker="o")
plt.plot(train_data["SalesID"],train_data["MachineHoursCurrentMeter"],marker="x")
plt.xlabel("SalesID")
plt.ylabel("Saleprice and machine per hour current meter")
plt.title("plotting of identites wrt Sales ID")
plt.legend(["S","M"])

# %%
iris_data=sns.load_dataset("iris")
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.petal_length.unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
t=iris_data.groupby("species")
t[["sepal_length","sepal_width","petal_length","petal_width"]].agg(["mean","max","min","sum","count"])
# Out:
#            sepal_length                        sepal_width                   \
#                    mean  max  min    sum count        mean  max  min    sum
# species
# setosa            5.006  5.8  4.3  250.3    50       3.428  4.4  2.3  171.4
# versicolor        5.936  7.0  4.9  296.8    50       2.770  3.4  2.0  138.5
# virginica         6.588  7.9  4.9  329.4    50       2.974  3.8  2.2  148.7
#
#                  petal_length                        petal_width            \
#            count         mean  max  min    sum count        mean  max  min
# species
# setosa        50        1.462  1.9  1.0   73.1    50       0.246  0.6  0.1
# versicolor    50        4.260  5.1  3.0  213.0    50       1.326  1.8  1.0
# virginica     50        5.552  6.9  4.5  277.6    50       2.026  2.5  1.4
#
#
#               sum count
# species
# setosa       12.3    50
# versicolor   66.3    50
# virginica   101.3    50

# %%
sns.lineplot(iris_data.sepal_length,iris_data.sepal_width)
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.plot(iris_data.sepal_length,iris_data.sepal_width)

# %%
sns.scatterplot(iris_data.sepal_length,iris_data.sepal_width)
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(iris_data.sepal_length,iris_data.sepal_width,hue=iris_data.species,s=100)
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(20,10))
plt.title("Sepal sizes")

sns.scatterplot(iris_data.sepal_length,iris_data.sepal_width,hue=iris_data.species,s=100)


## Seaborn is built over matplotlib libraray so, we can use both seaborn and matplotlib on same line of codes.
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:title={'center':'Sepal sizes'}, xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot("sepal_length","sepal_width",hue="species",data=iris_data,s=20)
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.title("sepal_length")
plt.hist(iris_data.sepal_length,bins=20)
plt.hist(iris_data.sepal_length,bins=np.arange(3,8.5,0.15),alpha=0.5)
# Out:
# (array([ 0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.,  3.,  5.,  2., 11.,
#         10., 13.,  1., 13.,  6., 15.,  3., 12.,  4., 16.,  5., 10.,  3.,
#          5.,  1.,  4.,  1.,  1.,  4.,  1.,  0.,  0.,  0.]),
#  array([3.  , 3.15, 3.3 , 3.45, 3.6 , 3.75, 3.9 , 4.05, 4.2 , 4.35, 4.5 ,
#         4.65, 4.8 , 4.95, 5.1 , 5.25, 5.4 , 5.55, 5.7 , 5.85, 6.  , 6.15,
#         6.3 , 6.45, 6.6 , 6.75, 6.9 , 7.05, 7.2 , 7.35, 7.5 , 7.65, 7.8 ,
#         7.95, 8.1 , 8.25, 8.4 ]),
#  <BarContainer object of 36 artists>)

# %%
plt.hist(iris_data.sepal_length,iris_data.sepal_width,alpha=0.5,stacked=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-7eb376533416> in <module>
# ----> 1 plt.hist(iris_data.sepal_length,iris_data.sepal_width,alpha=0.5,stacked=True)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
sns.barplot(iris_data.species,iris_data.sepal_width)
# Out:
# C:\Users\visha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = pd.DataFrame({
    'Height': [160, 165, 170, 175, 180, 185, 190, 195],
    'Weight': [60, 65, 70, 75, 80, 85, 90, 95],
    'Age': [25, 30, 35, 40, 45, 50, 55, 60]
})

# Create a pairplot with regression lines and markers
sns.pairplot(data, kind='reg', markers='*', plot_kws={'line_kws': {'color': 'red'}})
plt.show()

# %% [markdown]
# ![image.png](attachment:3880d0f7-c8a2-4ec7-a11b-d9f254ae3e02.png)
